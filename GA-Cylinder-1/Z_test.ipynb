# %%
import scipy.io as sio
import numpy as np

DATA = sio.loadmat('A.mat')
A = DATA['A']
A1 = A[0][0]
print(type(float(A1[0][0])))
A2 = A[0][1]
print(type(A2[0][0]))
C = (0.0,float(A1[0][0]),0.0)
print(C)
print(type(C))
# Out:
# <class 'float'>
# <class 'numpy.float64'>
# (0.0, 1.0, 0.0)
# <class 'tuple'>

# %%
# Out:
# 4

# %%
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 7
# 8
# 9

# %%
import scipy.io as sio
import numpy as np
DATA = sio.loadmat('AA.mat')
A = DATA['AA']
B = A[0][0]
print(A)
print(B)
print(np.size(B,0))
